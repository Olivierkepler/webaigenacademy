# %% [markdown]
# # Classification Error
#
# Placeholder notebook for classification error practice.

# %%
# TODO: Compute classification error
class_counts = [6, 4]
total = sum(class_counts)
majority = max(class_counts) / total
error = 1 - majority
print(f"Classification error: {error:.3f}")
