# %% [markdown]
# # Entropy
#
# Placeholder notebook for entropy practice.

# %%
import math

# TODO: Compute entropy for a two-class distribution
probs = [0.6, 0.4]
entropy = -sum(p * math.log2(p) for p in probs if p > 0)
print(f"Entropy: {entropy:.3f}")
