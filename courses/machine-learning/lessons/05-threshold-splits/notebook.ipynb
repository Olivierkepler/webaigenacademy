# %% [markdown]
# # Threshold Splits
#
# Placeholder notebook for threshold split practice.

# %%
# TODO: Split a small dataset by threshold
X = [1, 2, 3, 4]
threshold = 2.5
left = [x for x in X if x <= threshold]
right = [x for x in X if x > threshold]
print("Left:", left)
print("Right:", right)
